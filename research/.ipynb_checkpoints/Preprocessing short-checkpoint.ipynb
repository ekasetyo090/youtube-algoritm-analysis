# %% [markdown]
# # Preprocessing Short Video Data

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
pd.options.mode.copy_on_write = True 
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv(f'C:/Users/snsv/Documents/Data Analyst/personal youtube analysis/data/home/short_on_home_0.csv')
for i in range(1,69,1):
    temp_data_1 = pd.read_csv(f'C:/Users/snsv/Documents/Data Analyst/personal youtube analysis/data/home/short_on_home_{i}.csv')
    df = pd.concat([df,temp_data_1],axis=0,ignore_index=True)

# %% [markdown]
# ## Data Preview

# %%
df
# Out:
#         short_id                                     short_headline  \
# 0    yeseJ_WyvQg  Maomao's new little student😂😂 [The Apothecary ...
# 1    -14BImgVENA                The mean, the median, and the mode.
# 2    rzyX9cHTV2Y                        Sprinters Fighting For It 😅
# 3    DxN6u3_MkuQ  sok”an cinta lo dek, rapor lu benerin dlo #cov...
# 4    TIXpAHkgqQM       Hololive Kobo Kanaeru Realistic AI Generated
# ..           ...                                                ...
# 717  fkWN6JV5En0  This BUFFED WSP-9 MILANO Class Is Now INSANE O...
# 718  XC4NeFejl_w  She finally Found the truth about Dietrich dea...
# 719  7WVb0xw8KJI  Teman Mengerjai Dia Pertama Kali 😂 #pendek #sa...
# 720  OQt_EkR0vJw  DO YOU LOVE HELPING THE HOMELESS write ✍️ ??? ...
# 721  7Wvs7PqfBmQ  i think she's really fall in love with him #an...
#
#     short_view_count                  url                 time_record
# 0          37K views  /shorts/yeseJ_WyvQg  2024-03-13 23:04:58.067234
# ...

# %% [markdown]
# ## Descriptive Statistics

# %%
df.describe().transpose()
# Out:
#                  count unique                         top freq
# short_id           722    290                 QgNxrHxfEcc    4
# short_headline     722    286           Free Palestine 🇵🇸    9
# short_view_count   722    212                  2.3M views   14
# url                722    290         /shorts/QgNxrHxfEcc    4
# time_record        722      1  2024-03-13 23:04:58.067234  722

# %% [markdown]
# ## Data Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 722 entries, 0 to 721
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   short_id          722 non-null    object
#  1   short_headline    722 non-null    object
#  2   short_view_count  722 non-null    object
#  3   url               722 non-null    object
#  4   time_record       722 non-null    object
# dtypes: object(5)
# memory usage: 28.3+ KB

# %% [markdown]
# ## Value Count

# %%
for i in df.columns:
    print(f'\n------ Column {i}------')
    print(f'------ Total Lenght {len(df[i])}------')
    print(df[i].value_counts())
# Out:
# ------ Column short_id------
# ------ Total Lenght 722------
# short_id
# QgNxrHxfEcc    4
# GXxjd1za6jk    4
# pyo-D9aZK00    4
# e85uddgvxw0    4
# F5OrfBmqTzg    4
# Q2Un5pK6PfY    4
# cuwzOp7EXBE    4
# KEEx05M77uc    4
# 5M73IDKLceE    4
# E51ia5g3P5A    4
# 7sNdlMlPhB0    4
# sPOxkFwhfpg    4
# W_cZ4oAFsxo    4
# FTcKUuiE0IM    4
# jP92oR3Hv9E    4
# AxVGW9rhmgo    4
# IIkm-SGfddY    4
# iEMWMXlkM7I    4
# cfSMdhd4rxg    4
# -sp_WeWft9g    4
# eS8C14NW0Xo    4
# AKU-N3GSzpw    4
# iE-9ZXicO1k    4
# gsQGGVEHnZU    4
# Y1krrIpLyQE    4
# IKdicJkPFoo    4
# 9cUHBkrusFc    4
# srdrgkxDGPQ    4
# iJWt0lWaJDo    4
# VJBy0h2o9WI    4
# vjGhb_vo8vM    4
# u60LaEdrGLM    4
# pF1FgdE0-hM    4
# Fh49WJULyeg    4
# DsXiOAxi9Co    4
# sWJJ127N4dw    4
# rQ6hvgqY2oY    4
# 7g1OkmMPq-4    4
# 953NHzFtGHc    4
# exKTeAOxcbw    4
# IvPCotAAjyk    4
# UJMapdgFdPQ    4
# dI_ioCQgFp4    4
# T2Oaj_CgUJo    4
# XHBuGJ4Zc6w    4
# zNVL-L3uUp4    4
# lKJ9uKeluAQ    4
# mqE-6zeTcdw    4
# ...

# %% [markdown]
# ## Transform Views Data
# ### Transform Function

# %%
def view_to_numeric(x):
    identifier = {'K':1000,'M':1000000}
    spliter = x.split(' views')
    if spliter[0][-1] in identifier.keys():
        num  = float(spliter[0][:-1])*identifier.get(spliter[0][-1])
        return(round(num))
    else: 
        return x

# %% [markdown]
# ### Transforming Data

# %%
df['short_view_count'] = df['short_view_count'].apply(lambda row: view_to_numeric(row))

# %% [markdown]
# ## Spliting Headline Per Word

# %%
df['short_headline'] = df['short_headline'].apply(lambda row: row.lower().split(' '))

# %% [markdown]
# ## Save Data

# %%
df.to_csv('C:/Users/snsv/Documents/Data Analyst/personal youtube analysis/data/preprocessed/home_short.csv',index=False)
